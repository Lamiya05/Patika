# %% [markdown]
# <a href="https://colab.research.google.com/github/Lamiya05/Patika/blob/main/Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e091dcee-ff3d-447e-b070-8b3d8651ad0f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e091dcee-ff3d-447e-b070-8b3d8651ad0f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8a953685-d783-4f47-808f-85ea363320fb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8a953685-d783-4f47-808f-85ea363320fb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('GoogleApps.csv')
df
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                   Coloring book moana       ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                 ...                  ...
# 7347                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 7348                                      FR Calculator               FAMILY
# 7349                                   Sya9a Maroc - FR               FAMILY
# 7350                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 7351      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             7352 non-null   object
#  1   Category        7352 non-null   object
#  2   Rating          7352 non-null   float64
#  3   Reviews         7352 non-null   int64
#  4   Size            7352 non-null   float64
#  5   Installs        7352 non-null   float64
#  6   Type            7352 non-null   object
#  7   Price           7352 non-null   float64
#  8   Content Rating  7352 non-null   object
#  9   Last Updated    7352 non-null   object
#  10  Current Ver     7352 non-null   object
#  11  Android Ver     7352 non-null   object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 689.4+ KB

# %%
df[df['Rating']>4.9]
#rating 4.9 dan boyuk olanlari yazir
# Out:
#                                    App   Category  Rating  Reviews  Size  \
# 237       Hojiboy Tojiboyev Life Hacks     COMICS     5.0       15  37.0
# 316              Spine- The dating app     DATING     5.0        5   9.3
# 530                   SUMMER SONIC app     EVENTS     5.0        4  61.0
# 532                         Prosperity     EVENTS     5.0       16   2.3
# 536          Mindvalley U Tallinn 2018     EVENTS     5.0        1  21.0
# ...                                ...        ...     ...      ...   ...
# 7272                 Mad Dash Fo' Cash       GAME     5.0       14  16.0
# 7289             GKPB FP Online Church  LIFESTYLE     5.0       32   7.9
# 7308                  Monster Ride Pro       GAME     5.0        1  24.0
# 7341                   Fr. Daoud Lamei     FAMILY     5.0       22   8.6
# 7350  Fr. Mike Schmitz Audio Teachings     FAMILY     5.0        4   3.6
#
#       Installs  Type  Price Content Rating       Last Updated Current Ver  \
# ...

# %%
df[df['Rating']>4.9]['Installs']
# Out:
# 237     1000.0
# 316      500.0
# 530      500.0
# 532      100.0
# 536      100.0
#          ...
# 7272     100.0
# 7289    1000.0
# 7308      10.0
# 7341    1000.0
# 7350     100.0
# Name: Installs, Length: 258, dtype: float64

# %%
df[df['Rating']>4.9]['Installs'].mean()
#ratingi 4.9 dan boyuk olan yuklemelerin orta qiymeti
# Out:
# np.float64(331.40697674418607)

# %%
df[df['Price']>100].count()
# Out:
# App               15
# Category          15
# Rating            15
# Reviews           15
# Size              15
# Installs          15
# Type              15
# Price             15
# Content Rating    15
# Last Updated      15
# Current Ver       15
# Android Ver       15
# dtype: int64

# %%
df[df['Reviews']>100000].count()
# Out:
# App               1241
# Category          1241
# Rating            1241
# Reviews           1241
# Size              1241
# Installs          1241
# Type              1241
# Price             1241
# Content Rating    1241
# Last Updated      1241
# Current Ver       1241
# Android Ver       1241
# dtype: int64

# %%
df[df['Type']=='Paid']['Price'].min()
# Out:
# 0.99

# %%
df[df['Type']=='Free']['Reviews'].max()
# Out:
# 44893888

# %%
df[df['Type']=='Free']['Reviews'].min()
# Out:
# 1

# %%
df[df['Rating']>3]
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                   Coloring book moana       ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                 ...                  ...
# 7347                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 7348                                      FR Calculator               FAMILY
# 7349                                   Sya9a Maroc - FR               FAMILY
# 7350                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 7351      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df[df['Type']=='Paid']['Rating'].mean()
# Out:
# np.float64(4.247957371225577)

# %%
import pandas as pd
df = pd.read_csv("GoogleApps.csv")
print(df['Content Rating'].value_counts())
# Out:
# Content Rating
# Everyone        6166
# Teen             868
# Everyone 10+     318
# Name: count, dtype: int64

# %%
temp=df['Content Rating'].value_counts()
everyone=temp['Everyone']
everyone_plus=temp['Everyone 10+']
print(everyone/everyone_plus)
# Out:
# 19.38993710691824

# %%
df.groupby(by='Content Rating')['Size'].mean()
#butun content rating ucun tetbiqlerin orta Size tapmaq
# Out:
# Content Rating
# Everyone        20.397063
# Everyone 10+    40.733419
# Teen            33.041953
# Name: Size, dtype: float64

# %%
df.groupby(by='Category')['App'].count()
# Out:
# Category
# ART_AND_DESIGN           58
# AUTO_AND_VEHICLES        63
# BEAUTY                   36
# BOOKS_AND_REFERENCE     142
# BUSINESS                246
# COMICS                   42
# COMMUNICATION           206
# DATING                   16
# EDUCATION               108
# ENTERTAINMENT            84
# EVENTS                   38
# FAMILY                 1574
# FINANCE                 266
# FOOD_AND_DRINK           84
# GAME                    911
# HEALTH_AND_FITNESS      216
# HOUSE_AND_HOME           56
# LIBRARIES_AND_DEMO       61
# LIFESTYLE               275
# MAPS_AND_NAVIGATION      94
# MEDICAL                 318
# NEWS_AND_MAGAZINES      162
# PARENTING                43
# PERSONALIZATION         270
# PHOTOGRAPHY             231
# PRODUCTIVITY            234
# SHOPPING                176
# SOCIAL                  142
# SPORTS                  245
# TOOLS                   631
# TRAVEL_AND_LOCAL        159
# VIDEO_PLAYERS           114
# ...

# %%
a=df['Category'].value_counts()
print(a['BUSINESS'])
#business kateqoriyali app larin sayi
# Out:
# 246

# %%
b=df['Content Rating'].value_counts()
teen=b['Teen']
everyone_plus=b['Everyone 10+']
print(teen/everyone_plus)
# Out:
# 2.729559748427673

# %%
df.groupby(by='Type')['Rating'].mean()
#odenisli tetbiqlerin orta reytinqi
# Out:
# Type
# Free    4.171955
# Paid    4.247957
# Name: Rating, dtype: float64

# %%
df[df['Type']=='Paid']['Rating'].mean()
#diger usul
# Out:
# np.float64(4.247957371225577)

# %%
a=df[df['Type']=='Paid']['Rating'].mean()
b=df[df['Type']=='Free']['Rating'].mean()
print(a-b)
# Out:
# 0.0760027387318365

# %%
df.groupby(by='Content Rating')['Rating'].mean()
# Out:
# Content Rating
# Everyone        4.166542
# Everyone 10+    4.261006
# Teen            4.227074
# Name: Rating, dtype: float64

# %%
df.groupby(by='Type')['Size'].agg(['max','min'])
#odenisli ve odenissiz tetbiqlein olculerinin max ve min qiymetleri
# Out:
#         max       min
# Type
# Free  100.0  0.008301
# Paid  100.0  0.013672

# %%
df['Size'].max()
# Out:
# 100.0

# %%
df.groupby(by=['Type','Content Rating'])['Size'].agg(['min','max'])
# Out:
#                           min    max
# Type Content Rating
# Free Everyone        0.008301  100.0
#      Everyone 10+    0.027344  100.0
#      Teen            0.315430  100.0
# Paid Everyone        0.013672  100.0
#      Everyone 10+    1.800000  100.0
#      Teen            1.200000   99.0

# %%
df.groupby(by=['Content Rating','Type'])['Size'].agg(['min','max'])
# Out:
#                           min    max
# Content Rating Type
# Everyone       Free  0.008301  100.0
#                Paid  0.013672  100.0
# Everyone 10+   Free  0.027344  100.0
#                Paid  1.800000  100.0
# Teen           Free  0.315430  100.0
#                Paid  1.200000   99.0

# %%
temp=df.groupby(by=['Content Rating','Type'])['Size'].agg(['min','max'])
print(temp['max']['Teen']['Paid'])
# Out:
# 99.0

# %%
temp = df.groupby(by = ['Type', 'Content Rating'])['Size'].agg(['min', 'max'])
print(temp.reset_index())
# Out:
#    Type Content Rating       min    max
# 0  Free       Everyone  0.008301  100.0
# 1  Free   Everyone 10+  0.027344  100.0
# 2  Free           Teen  0.315430  100.0
# 3  Paid       Everyone  0.013672  100.0
# 4  Paid   Everyone 10+  1.800000  100.0
# 5  Paid           Teen  1.200000   99.0

# %%
temp = df.groupby(by = ['Type', 'Content Rating'])['Size'].agg(['min', 'max'])
temp=temp.reset_index()
print(temp[temp['min']>1])
#“10 yaşdan yuxarı” və “Yeniyetmələr” auditoriyalı ödənişli tətbiqlərin
#minimal ölçüsü 1-dən böyükdür.
# Out:
#    Type Content Rating  min    max
# 4  Paid   Everyone 10+  1.8  100.0
# 5  Paid           Teen  1.2   99.0

# %%
print(round(df.groupby(by = ['Type','Content Rating'])['Rating'].agg(['min','mean','max']), 1))
# Out:
#                      min  mean  max
# Type Content Rating
# Free Everyone        1.0   4.2  5.0
#      Everyone 10+    1.8   4.3  5.0
#      Teen            2.0   4.2  5.0
# Paid Everyone        1.0   4.2  5.0
#      Everyone 10+    3.4   4.3  4.7
#      Teen            3.4   4.4  5.0

# %%
temp=df.groupby(by=['Category','Type'])['Rating'].agg(['min','max','mean'])
temp[temp['mean']<=4]
# Out:
#                           min  max      mean
# Category            Type
# DATING              Free  2.8  5.0  4.000000
#                     Paid  2.6  2.6  2.600000
# FINANCE             Paid  1.7  4.7  3.830769
# MAPS_AND_NAVIGATION Paid  2.8  4.5  3.700000
# SOCIAL              Paid  3.2  4.2  3.700000
# VIDEO_PLAYERS       Paid  3.1  3.1  3.100000

# %%
temp=df.groupby(by=['Type','Content Rating'])['Size'].agg(['min','max'])
temp=temp.reset_index()
print(temp[temp['min']>1])
#min ölçüsü 1-dən böyük olan tətbiq növlərini və hədəf auditoriyasını necə müəyyən etmək olar?
# Out:
#    Type Content Rating  min    max
# 4  Paid   Everyone 10+  1.8  100.0
# 5  Paid           Teen  1.2   99.0

# %%
pd.isnull(df)
# Out:
#         App  Category  Rating  Reviews   Size  Installs   Type  Price  \
# 0     False     False   False    False  False     False  False  False
# 1     False     False   False    False  False     False  False  False
# 2     False     False   False    False  False     False  False  False
# 3     False     False   False    False  False     False  False  False
# 4     False     False   False    False  False     False  False  False
# ...     ...       ...     ...      ...    ...       ...    ...    ...
# 7347  False     False   False    False  False     False  False  False
# 7348  False     False   False    False  False     False  False  False
# 7349  False     False   False    False  False     False  False  False
# 7350  False     False   False    False  False     False  False  False
# 7351  False     False   False    False  False     False  False  False
#
#       Content Rating  Last Updated  Current Ver  Android Ver
# 0              False         False        False        False
# ...

# %%
pd.isnull(df['Rating']).head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Rating, dtype: bool

# %%
print(df[pd.isnull(df['Rating'])].head(2))
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df['Rating'].fillna(-1,inplace=True)
#nan olan setirleri -1 le evez edir

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             7352 non-null   object
#  1   Category        7352 non-null   object
#  2   Rating          7352 non-null   float64
#  3   Reviews         7352 non-null   int64
#  4   Size            7352 non-null   float64
#  5   Installs        7352 non-null   float64
#  6   Type            7352 non-null   object
#  7   Price           7352 non-null   float64
#  8   Content Rating  7352 non-null   object
#  9   Last Updated    7352 non-null   object
#  10  Current Ver     7352 non-null   object
#  11  Android Ver     7352 non-null   object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 689.4+ KB

# %%
df.dropna()
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                   Coloring book moana       ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                 ...                  ...
# 7347                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 7348                                      FR Calculator               FAMILY
# 7349                                   Sya9a Maroc - FR               FAMILY
# 7350                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 7351      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-03d74414-ce94-4e99-b8a1-4da5e2bd38b2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-03d74414-ce94-4e99-b8a1-4da5e2bd38b2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('googleplaystore.csv')
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Rating'].fillna(-1,inplace=True)
# Out:
# <ipython-input-121-a79849cf872b>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Rating'].fillna(-1,inplace=True)

# %%
print(sum(pd.isnull(df['Android Ver'])))
# Datasetdə ('NaN') android-versiya ('Android Ver') göstərilməyən neçə tətbiq var?
# Out:
# 3

# %%
print(len(df[pd.isnull(df['Android Ver'])]))
# Out:
# 3

# %%
print(df[pd.isnull(df['Current Ver'])])
## Cari versiyası (Current Ver) göstərilməyən son beş tətbiq haqqında məlumatı əks etdirin.
# Out:
#                                    App             Category  Rating Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2      55
# 1553              Market Update Helper   LIBRARIES_AND_DEMO     4.1   20145
# 6322            Virtual DJ Sound Mixer                TOOLS     4.2    4010
# 6803                         BT Master               FAMILY    -1.0       0
# 7333                       Dots puzzle               FAMILY     4.0     179
# 7407                   Calculate My IQ               FAMILY    -1.0      44
# 7730                            UFO-CQ                TOOLS    -1.0       1
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE    -1.0       8
#
#        Size    Installs  Type  Price Content Rating             Genres  \
# 15     2.7M      5,000+  Free      0       Everyone       Art & Design
# 1553    11k  1,000,000+  Free      0       Everyone   Libraries & Demo
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
def make_price(price):
  if price == '0':
    return float(price[1:])
  return 0
df['Price']= df['Price'].apply(make_price)
df.info()
  #tipin deyisdi
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  int64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.1+ MB

# %%
def set_size(size):
    if size[-1]=='M':
        return float(size[:-1])
    elif size[-1]=='k':
        return float(size[:-1])/1024
    return -1
df['Size'] = df['Size'].apply(set_size)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  int64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.1+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  float64
#  5   Installs        0 non-null      object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  int64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.1+ MB

# %%
temp=df.groupby(by=['Category'])['Size'].agg(['max'])
print(temp['max']['TOOLS'])
# Out:
# 99.0

# %%
df.groupby(by=['Category'])['Size'].agg(['max'])
# Out:
#                        max
# Category
# 1.9                   -1.0
# ART_AND_DESIGN        39.0
# AUTO_AND_VEHICLES     97.0
# BEAUTY                57.0
# BOOKS_AND_REFERENCE   87.0
# BUSINESS              98.0
# COMICS                40.0
# COMMUNICATION         66.0
# DATING                77.0
# EDUCATION             97.0
# ENTERTAINMENT         78.0
# EVENTS                61.0
# FAMILY               100.0
# FINANCE              100.0
# FOOD_AND_DRINK        76.0
# GAME                 100.0
# HEALTH_AND_FITNESS   100.0
# HOUSE_AND_HOME        77.0
# LIBRARIES_AND_DEMO    99.0
# LIFESTYLE            100.0
# MAPS_AND_NAVIGATION   78.0
# MEDICAL              100.0
# NEWS_AND_MAGAZINES    62.0
# PARENTING             98.0
# PERSONALIZATION       91.0
# PHOTOGRAPHY           96.0
# PRODUCTIVITY          76.0
# SHOPPING              98.0
# SOCIAL                96.0
# SPORTS               100.0
# TOOLS                 99.0
# TRAVEL_AND_LOCAL      90.0
# VIDEO_PLAYERS         91.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
s = pd.Series(data = [10, 5, 15, 20, 10],
index = [1, 2, 3, 4, 5])#Series-i əl ilə yaradırıq
s.plot()
plt.show()

# %%
df['Size'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Size'].plot(kind = 'hist', bins = 5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(x = 'Rating', y = 'Size', kind = 'scatter')
# Out:
# <Axes: xlabel='Rating', ylabel='Size'>

# %%
df['Rating'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Category'].value_counts().plot(kind = 'barh', figsize = (8, 5))
# Out:
# <Axes: ylabel='Category'>

# %%
df['Category'].value_counts().plot(kind = 'barh', figsize = (8, 5), grid = True)
# Out:
# <Axes: ylabel='Category'>

# %%
d=df.groupby(by = ['Type','Content Rating'])['Installs'].agg(['mean'])

# %%
d.plot(kind = 'barh', grid = True)

plt.show()
